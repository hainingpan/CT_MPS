# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
dir_path='../control_transition'
sys.path.append(dir_path)

# %%
from plot_utils import *

# %%
from importlib import reload


import plot_utils
reload(plot_utils)
from plot_utils import *

# %%
from diffusion_utils import *

# %%
from importlib import reload


import diffusion_utils
reload(diffusion_utils)
from diffusion_utils import *

# %%
params_list=[
({'nu':0,'de':1,},{'p_ctrl':[0.4,0.5,0.6],'p_proj':np.linspace(0.0,0.0,1),'s':np.arange(10000),'L':[10,20,30,40,50,60]}),
]

# %%
zip_fn=os.path.join('/home/jake/Data','MPS_0-1_coherence.zip')

# %%
z=zipfile.ZipFile(zip_fn, 'r')

# %%
zz=load_zip_json('MPS_(0,1)_L10_pctrl0.400_pproj0.000_s935_coherence.json',z)

# %%
zz.keys()
# Out:
# dict_keys(['args', 'coh_mat'])

# %%
np.array(zz['coh_mat']).shape
# Out:
# (11, 11, 201)

# %%
L=10
coh_mat=np.array(zz['coh_mat'])[:,:,L**2:2*L**2].sum(axis=(0,1))

# %%
plt.plot(coh_mat)

# %%
plt.imshow(np.array(zz['coh_mat'])[:,:,-1])

# %%
np.array(zz['coh_mat'])[:,:,-1].sum()
# Out:
# 2.8427368797257553

# %%
# zz=load_json('MPS_(0,1)_L8_pctrl0.050_pproj0.000_s0_coherence.json')
zz_1=load_json('MPS_(0,1)_L8_pctrl0.050_pproj0.000_s0_coherence_original.json')
# zz=load_json('MPS_(0,1)_L4_pctrl0.000_pproj0.000_s0_coherence.json')

# %%
np.array(zz['coh_mat'])[:,:,-4]

# %%
np.array(zz_1['coh_mat'])[:,:,-4]

# %%
np.array(zz['coh_mat'])[:,:,-4]

# %%
plt.imshow((np.array(zz_1['coh_mat'])[:,:,-5]))

# %%
from opt_einsum import contract

# %%
plt.imshow(np.log10(contract(zz_1['coh_mat'],[0,0,1],[0,1]).T),cmap='Blues')
plt.ylim(0,40)
plt.colorbar()
# Out:
# /tmp/ipykernel_1534403/117310507.py:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(contract(zz_1['coh_mat'],[0,0,1],[0,1]).T),cmap='Blues')
# /tmp/ipykernel_1534403/117310507.py:1: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(contract(zz_1['coh_mat'],[0,0,1],[0,1]).T),cmap='Blues')

# %%
plt.imshow(np.log10(contract(zz['coh_mat'],[0,0,1],[0,1]).T),cmap='Blues')
plt.ylim(0,40)
plt.colorbar()
# Out:
# /tmp/ipykernel_1534403/4275730439.py:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(contract(zz['coh_mat'],[0,0,1],[0,1]).T),cmap='Blues')

# %%
plt.imshow(np.log10(contract(zz['coh_mat'],[0,0,1],[0,1]).T),cmap='Blues')
plt.ylim(0,40)
plt.colorbar()
# Out:
# /tmp/ipykernel_1534403/4275730439.py:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(contract(zz['coh_mat'],[0,0,1],[0,1]).T),cmap='Blues')

# %%
plt.imshow(np.log10(np.array(zz['coh_mat'])[0,:,:].T),cmap='Blues',vmin=-3)
plt.ylim(0,40)
plt.colorbar()
# Out:
# /tmp/ipykernel_1534403/675947525.py:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(np.array(zz['coh_mat'])[0,:,:].T),cmap='Blues',vmin=-3)

# %%
plt.imshow(np.log10(np.array(zz['coh_mat'])[0,:,:].T),cmap='Blues',vmin=-3)
plt.ylim(0,40)
plt.colorbar()
# Out:
# /tmp/ipykernel_1534403/675947525.py:1: RuntimeWarning: divide by zero encountered in log10
#   plt.imshow(np.log10(np.array(zz['coh_mat'])[0,:,:].T),cmap='Blues',vmin=-3)
